# %% [markdown]
# <a href="https://colab.research.google.com/github/bbamknp2018/MSC_DPDM_2025/blob/main/Data101_(dpdm24)_Chapter2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Data101_(Chapter2)

# %% [markdown]
# **pandas** คือ package ที่มีคนพัฒนาขึ้นมาเพื่อใช้จัดการข้อมูลที่มีลักษณะเป็นตาราง ซึ่งใน pandas เรียกว่า DataFrame
#
# **pandas** is a package for manage table data. pandas data structure for table is DataFrame

# %%
import pandas #import pandas คือ โหลด package มีชื่อว่า pandas มาใช้ (We use import to pandas define a package that we are using)

# %%
pandas.DataFrame({'A':[1,2,3], 'B':[2,3,4]})
# Out:
#    A  B
# 0  1  2
# 1  2  3
# 2  3  4

# %%
import pandas as pd # โหลด pandas package แล้วตั้งชื่อให้ว่า pd แทน (import pakage and name it as ...)

# %%
pd.read_csv('/content/2025-01-suffolk-stop-and-search.csv')
# Out:
#               Type                       Date  Part of a policing operation  \
# 0    Person search  2025-01-01T00:50:00+00:00                         False
# 1    Person search  2025-01-01T00:52:00+00:00                         False
# 2    Person search  2025-01-01T01:06:10+00:00                         False
# 3    Person search  2025-01-01T01:09:34+00:00                         False
# 4    Person search  2025-01-01T01:28:00+00:00                         False
# ..             ...                        ...                           ...
# 190  Person search  2025-01-31T20:46:00+00:00                         False
# 191  Person search  2025-01-31T20:46:00+00:00                         False
# 192  Person search  2025-01-31T20:46:00+00:00                         False
# 193  Person search  2025-01-31T21:40:00+00:00                         False
# 194  Person search  2025-01-31T21:40:03+00:00                         False
#
# ...

# %%
SS_df[SS_df.isnull()['Officer-defined ethnicity']] #ค่าในOfficer-defined ethnicityเป็น NaN ดูว่าค่าผิดปกติยังไง
# Out:
#               Type                       Date  Part of a policing operation  \
# 75   Person search  2025-01-13T20:42:36+00:00                         False
# 76   Person search  2025-01-14T05:35:54+00:00                         False
# 102  Person search  2025-01-16T10:21:22+00:00                         False
# 118  Person search  2025-01-18T18:55:42+00:00                         False
# 130  Person search  2025-01-19T15:48:00+00:00                         False
# 160  Person search  2025-01-26T21:50:00+00:00                         False
#
#      Policing operation   Latitude  Longitude Gender Age range  \
# 75                  NaN  52.056605   1.152581   Male     25-34
# 76                  NaN  52.488953   1.757943  Other       NaN
# 102                 NaN  52.077919   0.428721   Male   over 34
# 118                 NaN  52.423712   0.583849  Other       NaN
# 130                 NaN  52.057407   1.161610   Male     25-34
# ...

# %%
#Quiz 6 แสดงว่า  row ทั้งหมดที่ผู้ต้องอาศัยมีอายุอยู่ระหว่าง 10-17ปี
SS_df[SS_df['Age range'] == '10-17']
# Out:
#               Type                       Date  Part of a policing operation  \
# 7    Person search  2025-01-01T22:04:37+00:00                         False
# 12   Person search  2025-01-02T20:20:46+00:00                         False
# 37   Person search  2025-01-06T19:55:57+00:00                         False
# 38   Person search  2025-01-06T20:04:43+00:00                         False
# 39   Person search  2025-01-06T20:07:19+00:00                         False
# 48   Person search  2025-01-09T18:23:28+00:00                         False
# 49   Person search  2025-01-09T18:40:00+00:00                         False
# 59   Person search  2025-01-10T11:44:34+00:00                         False
# 60   Person search  2025-01-10T17:22:49+00:00                         False
# 70   Person search  2025-01-13T09:04:53+00:00                         False
# 86   Person search  2025-01-15T12:12:17+00:00                         False
# ...

# %%
SS_df = pd.read_csv('/content/2025-01-suffolk-stop-and-search.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4022657349.py in <cell line: 0>()
# ----> 1 SS_df = pd.read_csv('/content/2025-01-suffolk-stop-and-search.csv')
#
# NameError: name 'pd' is not defined

# %%
#เด็กเชื้อชาติถูกจับมากที่สุด
kids = SS_df[SS_df['Age range'] == '10-17']
display(kids['Self-defined ethnicity'].value_counts())
# Out:
# Self-defined ethnicity
# White - English/Welsh/Scottish/Northern Irish/British    24
# Other ethnic group - Not stated                           6
# White - Any other White background                        2
# Name: count, dtype: int64

# %%
SS_df[SS_df['Age range'] == '10-17'].groupby('Self-defined ethnicity').count()
# Out:
#                                                     Type  Date  \
# Self-defined ethnicity
# Other ethnic group - Not stated                        6     6
# White - Any other White background                     2     2
# White - English/Welsh/Scottish/Northern Irish/B...    24    24
#
#                                                     Part of a policing operation  \
# Self-defined ethnicity
# Other ethnic group - Not stated                                                6
# White - Any other White background                                             2
# White - English/Welsh/Scottish/Northern Irish/B...                            24
#
#                                                     Policing operation  \
# Self-defined ethnicity
# Other ethnic group - Not stated                                      0
# White - Any other White background                                   0
# White - English/Welsh/Scottish/Northern Irish/B...                   0
#
# ...

# %%
#เด็กเชื้อชาติถูกจับมากที่สุด ถูกตำรวจเชื้อชาติไหนจับ
SS_df[SS_df['Age range'] == '10-17'].groupby(['Self-defined ethnicity','Officer-defined ethnicity']).count()
# Out:
#                                                                               Type  \
# Self-defined ethnicity                             Officer-defined ethnicity
# Other ethnic group - Not stated                    Other                         1
#                                                    White                         5
# White - Any other White background                 White                         2
# White - English/Welsh/Scottish/Northern Irish/B... White                        24
#
#                                                                               Date  \
# Self-defined ethnicity                             Officer-defined ethnicity
# Other ethnic group - Not stated                    Other                         1
#                                                    White                         5
# White - Any other White background                 White                         2
# ...

# %%
#Quiz 7 เปรียบเทียบว่าตำรวจที่เป็น Asian และ Black ชอบเรียกค้นคนอายุเท่าไหร่และเชื้อชาติไหน ต่างกันอย่างไร
SS_df1 = pd.read_csv('/content/2025-01-warwickshire-stop-and-search.csv')
SS_df1
# Out:
#                          Type                       Date  \
# 0               Person search  2025-01-01T02:16:00+00:00
# 1               Person search  2025-01-01T23:21:00+00:00
# 2   Person and Vehicle search  2025-01-01T23:21:00+00:00
# 3               Person search  2025-01-01T23:35:00+00:00
# 4               Person search  2025-01-01T23:45:00+00:00
# ..                        ...                        ...
# 89  Person and Vehicle search  2025-01-31T03:38:00+00:00
# 90  Person and Vehicle search  2025-01-31T04:07:00+00:00
# 91              Person search  2025-01-31T14:12:00+00:00
# 92              Person search  2025-01-31T14:25:00+00:00
# 93              Person search  2025-01-31T14:28:00+00:00
#
#     Part of a policing operation  Policing operation  Latitude  Longitude  \
# 0                          False                 NaN       NaN        NaN
# 1                          False                 NaN       NaN        NaN
# ...

# %%
# กรองเฉพาะตำรวจที่ระบุว่าเป็น Asian หรือ Black
subset = SS_df1[SS_df1['Officer-defined ethnicity'].isin(['Asian', 'Black'])]
subset
# Out:
#                          Type                       Date  \
# 1               Person search  2025-01-01T23:21:00+00:00
# 2   Person and Vehicle search  2025-01-01T23:21:00+00:00
# 3               Person search  2025-01-01T23:35:00+00:00
# 4               Person search  2025-01-01T23:45:00+00:00
# 8               Person search  2025-01-02T23:50:00+00:00
# 12              Person search  2025-01-03T19:20:00+00:00
# 19              Person search  2025-01-08T15:10:00+00:00
# 21  Person and Vehicle search  2025-01-09T05:07:00+00:00
# 23  Person and Vehicle search  2025-01-09T05:14:00+00:00
# 24              Person search  2025-01-09T14:12:00+00:00
# 27  Person and Vehicle search  2025-01-11T02:10:00+00:00
# 34  Person and Vehicle search  2025-01-13T15:39:00+00:00
# 38              Person search  2025-01-14T16:40:00+00:00
# 42  Person and Vehicle search  2025-01-14T23:39:00+00:00
# 44  Person and Vehicle search  2025-01-15T15:26:00+00:00
# ...

# %%
# --- เปรียบเทียบอายุ ---
age_comp = (
    subset.groupby(['Officer-defined ethnicity', 'Age range'])
    .size()
    .reset_index(name='count')
    .sort_values(['Officer-defined ethnicity','count'], ascending=[True, False])
)
age_comp
# Out:
#   Officer-defined ethnicity Age range  count
# 1                     Asian     18-24      6
# 2                     Asian     25-34      4
# 3                     Asian   over 34      2
# 0                     Asian     10-17      1
# 5                     Black     25-34      3
# 6                     Black   over 34      3
# 4                     Black     18-24      2

# %% [markdown]
# เจ้าหน้าที่ Asian
#
# 18–24 ปี ถูกค้นมากที่สุด → 6 ครั้ง
#
# รองลงมา 25–34 ปี → 3 ครั้ง
#
# over 34 ปี → 2 ครั้ง
#
# 10–17 ปี → 1 ครั้ง
#
# แปลว่า ตำรวจที่เป็น Asian มักเรียกค้นคนหนุ่มสาวอายุ 18–24 ปี มากที่สุด
#
# เจ้าหน้าที่ Black
#
# 25–34 ปี และ over 34 ปี ถูกค้นเท่ากัน → 3 ครั้ง
#
# 18–24 ปี → 2 ครั้ง
#
# (ไม่มีการค้นในกลุ่ม 10–17 ปี)
#
# แปลว่า ตำรวจที่เป็น Black กระจายการค้นไปในผู้ใหญ่วัยทำงาน (25 ปีขึ้นไป) มากกว่า โดย ไม่ค่อยมีการค้นเด็กอายุต่ำกว่า 18 ปีเลย
#
# สรุปเปรียบเทียบ
#
# Asian officers → โฟกัสที่วัยรุ่น/วัยเรียนตอนต้นมหาลัย (18–24 ปี)
#
# Black officers → โฟกัสที่วัยทำงานและผู้ใหญ่ (25–34 ปี และ over 34)
#
# เด็ก 10–17 ปี มีแค่กรณีเดียวที่โดนค้น และเกิดกับ Asian officers เท่านั้น

# %%
# --- เปรียบเทียบเชื้อชาติของผู้ถูกค้น ---
eth_comp = (
    subset.groupby(['Officer-defined ethnicity', 'Self-defined ethnicity'])
    .size()
    .reset_index(name='count')
    .sort_values(['Officer-defined ethnicity','count'], ascending=[True, False])
)
eth_comp
# Out:
#   Officer-defined ethnicity  \
# 2                     Asian
# 0                     Asian
# 1                     Asian
# 3                     Asian
# 4                     Black
# 8                     Black
# 5                     Black
# 6                     Black
# 7                     Black
# 9                     Black
#
#                               Self-defined ethnicity  count
# 2                    Asian/Asian British - Pakistani      7
# 0   Asian/Asian British - Any other Asian background      2
# 1                       Asian/Asian British - Indian      2
# 3                    Other ethnic group - Not stated      2
# 4    Black/African/Caribbean/Black British - African      3
# 8                    Other ethnic group - Not stated      2
# 5  Black/African/Caribbean/Black British - Any ot...      1
# 6  Black/African/Caribbean/Black British - Caribbean      1
# 7  Mixed/Multiple ethnic groups - White and Black...      1
# ...

# %% [markdown]
# Officer-defined ethnicity → เชื้อชาติของเจ้าหน้าที่ (Asian หรือ Black)
#
# Self-defined ethnicity → เชื้อชาติที่ผู้ถูกค้นนิยามตัวเอง
#
# count → จำนวนครั้งที่มีการค้นในคู่เชื้อชาตินั้น ๆ
#
# ผลลัพธ์จากตาราง
# ตำรวจที่เป็น Asian
#
# ค้น Asian/Asian British – Pakistani มากที่สุด → 7 ครั้ง
#
# รองลงมา:
#
# Asian/Asian British – Any other Asian background → 2 ครั้ง
#
# Asian/Asian British – Indian → 2 ครั้ง
#
# Other ethnic group – Not stated → 2 ครั้ง
#
# แปลว่า ตำรวจที่เป็น Asian มักจะเรียกค้นคนเชื้อชาติ เอเชีย (โดยเฉพาะ Pakistani) มากที่สุด
#
# ตำรวจที่เป็น Black
#
# ค้น Black/African/Caribbean/Black British – African → 3 ครั้ง
#
# Other ethnic group – Not stated → 2 ครั้ง
#
# นอกนั้น (เช่น Caribbean, Any other Black background, Mixed White & Black, White English/Welsh/Scottish/Northern Irish) → อย่างละ 1 ครั้ง
#
# แปลว่า ตำรวจที่เป็น Black มักจะเรียกค้นคนเชื้อชาติ Black (โดยเฉพาะ African) มากที่สุด

# %%
SS_df.shape
# Out:
# (195, 15)

# %%
SS_df1.head(7)
# Out:
#                         Type                       Date  \
# 0              Person search  2025-01-01T02:16:00+00:00
# 1              Person search  2025-01-01T23:21:00+00:00
# 2  Person and Vehicle search  2025-01-01T23:21:00+00:00
# 3              Person search  2025-01-01T23:35:00+00:00
# 4              Person search  2025-01-01T23:45:00+00:00
# 5              Person search  2025-01-02T10:30:00+00:00
# 6              Person search  2025-01-02T14:25:00+00:00
#
#    Part of a policing operation  Policing operation  Latitude  Longitude  \
# 0                         False                 NaN       NaN        NaN
# 1                         False                 NaN       NaN        NaN
# 2                         False                 NaN       NaN        NaN
# 3                         False                 NaN       NaN        NaN
# 4                         False                 NaN       NaN        NaN
# 5                         False                 NaN       NaN        NaN
# ...

# %%
SS_df1.tail()
# Out:
#                          Type                       Date  \
# 89  Person and Vehicle search  2025-01-31T03:38:00+00:00
# 90  Person and Vehicle search  2025-01-31T04:07:00+00:00
# 91              Person search  2025-01-31T14:12:00+00:00
# 92              Person search  2025-01-31T14:25:00+00:00
# 93              Person search  2025-01-31T14:28:00+00:00
#
#     Part of a policing operation  Policing operation  Latitude  Longitude  \
# 89                         False                 NaN       NaN        NaN
# 90                         False                 NaN       NaN        NaN
# 91                         False                 NaN       NaN        NaN
# 92                         False                 NaN       NaN        NaN
# 93                         False                 NaN       NaN        NaN
#
#     Gender Age range                             Self-defined ethnicity  \
# 89    Male     25-34  White - English/Welsh/Scottish/Northern Irish/...
# ...

# %%
SS_df1.dropna()
# Out:
# Empty DataFrame
# Columns: [Type, Date, Part of a policing operation, Policing operation, Latitude, Longitude, Gender, Age range, Self-defined ethnicity, Officer-defined ethnicity, Legislation, Object of search, Outcome, Outcome linked to object of search, Removal of more than just outer clothing]
# Index: []

# %%
#drop เฉพาะ column  ที่มีค่า missing มากกว่า 50%

# Calculate the percentage of missing values for each column
missing_percentage = SS_df1.isnull().mean() * 100

# Identify columns with more than 50% missing values
columns_to_drop = missing_percentage[missing_percentage > 50].index

# Drop the identified columns from the DataFrame
SS_warwick_cleaned = SS_df1.drop(columns=columns_to_drop)

# Display the first few rows of the cleaned DataFrame
display(SS_warwick_cleaned)
# Out:
#                          Type                       Date  \
# 0               Person search  2025-01-01T02:16:00+00:00
# 1               Person search  2025-01-01T23:21:00+00:00
# 2   Person and Vehicle search  2025-01-01T23:21:00+00:00
# 3               Person search  2025-01-01T23:35:00+00:00
# 4               Person search  2025-01-01T23:45:00+00:00
# ..                        ...                        ...
# 89  Person and Vehicle search  2025-01-31T03:38:00+00:00
# 90  Person and Vehicle search  2025-01-31T04:07:00+00:00
# 91              Person search  2025-01-31T14:12:00+00:00
# 92              Person search  2025-01-31T14:25:00+00:00
# 93              Person search  2025-01-31T14:28:00+00:00
#
#     Part of a policing operation  Gender Age range  \
# 0                          False  Female     18-24
# 1                          False    Male     18-24
# 2                          False    Male       NaN
# 3                          False    Male     18-24
# ...

# %%
# Drop เฉพาะคอลัมน์ที่เราสนใจ
SS_warwick_cleaned.dropna()
# Out:
#                          Type                       Date  \
# 0               Person search  2025-01-01T02:16:00+00:00
# 1               Person search  2025-01-01T23:21:00+00:00
# 3               Person search  2025-01-01T23:35:00+00:00
# 4               Person search  2025-01-01T23:45:00+00:00
# 6               Person search  2025-01-02T14:25:00+00:00
# ..                        ...                        ...
# 89  Person and Vehicle search  2025-01-31T03:38:00+00:00
# 90  Person and Vehicle search  2025-01-31T04:07:00+00:00
# 91              Person search  2025-01-31T14:12:00+00:00
# 92              Person search  2025-01-31T14:25:00+00:00
# 93              Person search  2025-01-31T14:28:00+00:00
#
#     Part of a policing operation  Gender Age range  \
# 0                          False  Female     18-24
# 1                          False    Male     18-24
# 3                          False    Male     18-24
# 4                          False    Male     18-24
# ...

# %%
SS_warwick_cleaned.dropna(subset=['Date','Gender','Age range','Officer-defined ethnicity'])
# Out:
#                          Type                       Date  \
# 0               Person search  2025-01-01T02:16:00+00:00
# 1               Person search  2025-01-01T23:21:00+00:00
# 3               Person search  2025-01-01T23:35:00+00:00
# 4               Person search  2025-01-01T23:45:00+00:00
# 5               Person search  2025-01-02T10:30:00+00:00
# ..                        ...                        ...
# 89  Person and Vehicle search  2025-01-31T03:38:00+00:00
# 90  Person and Vehicle search  2025-01-31T04:07:00+00:00
# 91              Person search  2025-01-31T14:12:00+00:00
# 92              Person search  2025-01-31T14:25:00+00:00
# 93              Person search  2025-01-31T14:28:00+00:00
#
#     Part of a policing operation  Gender Age range  \
# 0                          False  Female     18-24
# 1                          False    Male     18-24
# 3                          False    Male     18-24
# 4                          False    Male     18-24
# ...

# %% [markdown]
# #เติมค่า missing ที่เหลืออยู่ ด้วย dummy (ซึ่งต้องเติมด้วยเลขที่ไม่มีอยู่ในข้อมูล เพ่อสื่อว่าเป็นค่า missing) + เติมด้วยค่าที่น่าเป็นจากข้อมูลที่เรารู้

# %%
set(SS_warwick_cleaned['Part of a policing operation'])
# Out:
# {False, True}

# %%
SS_warwick_cleaned.fillna({'Part of a policing operation':False}, inplace=True)

# %%
SS_warwick_cleaned.fillna({'Part of a policing operation':False,
                   'Latitude':SS_warwick_cleaned['Latitude'].mean(),
                   'Longitude':SS_warwick_cleaned['Longitude'].mean()
                   })
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Latitude'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4246350173.py in <cell line: 0>()
#       1 SS_warwick_cleaned.fillna({'Part of a policing operation':False,
# ...

# %%
import pandas as pd

# %% [markdown]
# #เพิ่มข้อมูลโดยเอาเดือนอื่นมาต่อ

# %%
SS_df2 = pd.read_csv('/content/2025-01-city-of-london-stop-and-search.csv')
SS_df2
# Out:
#                           Type                       Date  \
# 0    Person and Vehicle search  2025-01-01T19:44:54+00:00
# 1    Person and Vehicle search  2025-01-01T19:53:21+00:00
# 2    Person and Vehicle search  2025-01-01T20:19:35+00:00
# 3    Person and Vehicle search  2025-01-01T23:12:51+00:00
# 4                Person search  2025-01-02T03:19:44+00:00
# ..                         ...                        ...
# 149  Person and Vehicle search  2025-01-31T11:28:02+00:00
# 150              Person search  2025-01-31T13:26:41+00:00
# 151              Person search  2025-01-31T13:40:18+00:00
# 152              Person search  2025-01-31T16:01:47+00:00
# 153              Person search  2025-01-31T22:29:53+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                             NaN                 NaN        NaN        NaN
# 1                             NaN                 NaN        NaN        NaN
# ...

# %%
SS_df2.isnull().all()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                 True
# Policing operation                           True
# Latitude                                    False
# Longitude                                   False
# Gender                                      False
# Age range                                   False
# Self-defined ethnicity                      False
# Officer-defined ethnicity                   False
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search          False
# Removal of more than just outer clothing    False
# dtype: bool

# %%
SS_df2.fillna({'Part of a policing operation':False,
                   'Latitude':SS_df2['Latitude'].mean(),
                   'Longitude':SS_df2['Longitude'].mean()
                   })
# Out:
# /tmp/ipython-input-2465466061.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   SS_df2.fillna({'Part of a policing operation':False,
#                           Type                       Date  \
# 0    Person and Vehicle search  2025-01-01T19:44:54+00:00
# 1    Person and Vehicle search  2025-01-01T19:53:21+00:00
# 2    Person and Vehicle search  2025-01-01T20:19:35+00:00
# 3    Person and Vehicle search  2025-01-01T23:12:51+00:00
# 4                Person search  2025-01-02T03:19:44+00:00
# ..                         ...                        ...
# 149  Person and Vehicle search  2025-01-31T11:28:02+00:00
# 150              Person search  2025-01-31T13:26:41+00:00
# 151              Person search  2025-01-31T13:40:18+00:00
# ...

# %%
SS_df2.isnull().all()
# Out:
# Type                                        False
# Date                                        False
# Part of a policing operation                 True
# Policing operation                           True
# Latitude                                    False
# Longitude                                   False
# Gender                                      False
# Age range                                   False
# Self-defined ethnicity                      False
# Officer-defined ethnicity                   False
# Legislation                                 False
# Object of search                            False
# Outcome                                     False
# Outcome linked to object of search          False
# Removal of more than just outer clothing    False
# dtype: bool

# %% [markdown]
# ตรวจสอบความสัมพันธ์

# %%
# --- เปรียบเทียบเชื้อชาติของผู้ถูกค้น ---
eth_comp = (
    SS_df2.groupby(['Gender', 'Self-defined ethnicity'])
    .size()
    .reset_index(name='count')
    .sort_values(['Gender','count'], ascending=[True, False])
)
eth_comp
# Out:
#     Gender                             Self-defined ethnicity  count
# 4   Female                    Other ethnic group - Not stated      9
# 0   Female    Black/African/Caribbean/Black British - African      5
# 5   Female                 White - Any other White background      3
# 6   Female  White - English/Welsh/Scottish/Northern Irish/...      3
# 1   Female  Black/African/Caribbean/Black British - Any ot...      1
# 2   Female  Black/African/Caribbean/Black British - Caribbean      1
# 3   Female  Mixed/Multiple ethnic groups - Any other Mixed...      1
# 18    Male                    Other ethnic group - Not stated     43
# 20    Male  White - English/Welsh/Scottish/Northern Irish/...     27
# 19    Male                 White - Any other White background     17
# 8     Male                  Asian/Asian British - Bangladeshi      6
# 10    Male                    Asian/Asian British - Pakistani      6
# 11    Male    Black/African/Caribbean/Black British - African      6
# ...

# %%
#เด็กเชื้อชาติถูกจับมากที่สุด ถูกตำรวจเชื้อชาติไหนจับ
SS_df2.groupby(['Gender','Age range']).count()
# Out:
#                   Type  Date  Part of a policing operation  \
# Gender Age range
# Female 10-17         1     1                             0
#        18-24         8     8                             0
#        25-34         9     9                             0
#        over 34       4     4                             0
# Male   10-17         6     6                             0
#        18-24        39    39                             0
#        25-34        38    38                             0
#        over 34      41    41                             0
#
#                   Policing operation  Latitude  Longitude  \
# Gender Age range
# Female 10-17                       0         1          1
#        18-24                       0         5          5
#        25-34                       0         8          8
#        over 34                     0         3          3
# Male   10-17                       0         5          5
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chisquare

# ==== ตั้งค่าคอลัมน์ ====
df = SS_df2.copy()              # <<-- เปลี่ยนตามชื่อ DataFrame ของเธอ
COL_AGE = 'Age range'
COL_GENDER = 'Gender'

# ==== ฟังก์ชันเล็ก ๆ ช่วยงาน ====
def mode_one(s: pd.Series):
    """คืนค่า mode ตัวแรก (ถ้าเสมอกันเลือกตัวแรก)"""
    m = s.mode(dropna=True)
    return m.iloc[0] if len(m) else np.nan

def distribution(s: pd.Series, order=None, normalize=True):
    vc = s.value_counts(dropna=False)
    if order is not None:
        vc = vc.reindex(order, fill_value=0)
    return (vc / vc.sum()) if normalize else vc

# ==== เก็บ distribution 'ก่อนเติม' (เฉพาะค่าที่ไม่ missing) ====
# (เอาไว้เป็น baseline เปรียบเทียบ)
# ถ้ามีชุด label มาตรฐาน ให้กำหนดเองเพื่อเรียงสวย ๆ
age_order = ['10-17','18-24','25-34','over 34']
baseline = distribution(df[COL_AGE].dropna(), order=age_order, normalize=True)

# ==== เติมแบบ 1) รวมเพศ (Global mode) ====
global_mode = mode_one(df[COL_AGE])
df_global = df.copy()
df_global[COL_AGE] = df_global[COL_AGE].fillna(global_mode)
dist_global = distribution(df_global[COL_AGE], order=age_order, normalize=True)

# ==== เติมแบบ 2) แยกเพศ (Conditional on Gender) ====
df_gender = df.copy()
# หา mode ของอายุในแต่ละเพศ
mode_by_gender = df_gender.groupby(COL_GENDER)[COL_AGE].apply(mode_one)

# เติมแถวที่ missing ด้วย mode ของเพศนั้น ๆ (ถ้าเพศใดไม่มีข้อมูลเลย ตกกลับไปใช้ global_mode)
def fill_by_gender(row):
    if pd.isna(row[COL_AGE]):
        g = row[COL_GENDER]
        return mode_by_gender.get(g, global_mode)
    return row[COL_AGE]

df_gender[COL_AGE] = df_gender.apply(fill_by_gender, axis=1)
dist_gender = distribution(df_gender[COL_AGE], order=age_order, normalize=True)

# ==== Chi-square (เช็คความใกล้เคียง distribution หลังเติมกับ baseline) ====
# ต้องทำให้ยอดรวมเท่ากันก่อน
def chisq_pvalue(baseline_counts, after_counts):
    # ใช้จำนวนดิบ (ไม่ normalize)
    b = baseline_counts.copy()
    a = after_counts.copy()
    # สเกล expected ให้รวมเท่ากับ observed
    expected = a * (b.sum() / a.sum())
    chi2, p = chisquare(f_obs=b.values, f_exp=expected.values)
    return chi2, p

baseline_counts = distribution(df[COL_AGE].dropna(), order=age_order, normalize=False)
global_counts   = distribution(df_global[COL_AGE],   order=age_order, normalize=False)
gender_counts   = distribution(df_gender[COL_AGE],   order=age_order, normalize=False)

chi2_g, p_g = chisq_pvalue(baseline_counts, global_counts)
chi2_cond, p_cond = chisq_pvalue(baseline_counts, gender_counts)

print(f"[Chi-square] รวมเพศ vs baseline: chi2={chi2_g:.3f}, p={p_g:.4f}")
print(f"[Chi-square] แยกเพศ vs baseline: chi2={chi2_cond:.3f}, p={p_cond:.4f}")

# ==== พล็อตเปรียบเทียบ ====
x = np.arange(len(age_order))
w = 0.25

plt.figure(figsize=(10,5))
plt.bar(x - w, baseline.reindex(age_order, fill_value=0), width=w, label='Before (non-missing)')
plt.bar(x,       dist_global.reindex(age_order, fill_value=0), width=w, label='After: Global-mode')
plt.bar(x + w,   dist_gender.reindex(age_order, fill_value=0), width=w, label='After: Gender-mode')
plt.xticks(x, age_order, rotation=0)
plt.ylabel('Proportion')
plt.title('Age range distribution: before vs imputed (mode)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# [Chi-square] รวมเพศ vs baseline: chi2=0.789, p=0.8521
# [Chi-square] แยกเพศ vs baseline: chi2=0.578, p=0.9015

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = SS_df2.copy()   # เปลี่ยนชื่อให้ตรงกับของเธอ
COL_AGE = 'Age range'
COL_GENDER = 'Gender'

# เลือกลำดับ bin ให้สวยงาม (ปรับได้)
age_order = ['10-17','18-24','25-34','over 34']

# mode แยกเพศ
female_mode = df.loc[df[COL_GENDER]=='Female', COL_AGE].mode(dropna=True)
female_mode = female_mode.iloc[0] if len(female_mode) else np.nan

male_mode = df.loc[df[COL_GENDER]=='Male', COL_AGE].mode(dropna=True)
male_mode = male_mode.iloc[0] if len(male_mode) else np.nan

female_mode, male_mode
# Out:
# ('25-34', 'over 34')

# %%
# ก่อนเติม (ไม่รวม missing)
before = df[COL_AGE].dropna()

# เติมด้วย mode เพศหญิง (ทุกแถวที่เป็น NaN)
df_f = df.copy()
df_f[COL_AGE] = df_f[COL_AGE].fillna(female_mode)

# เติมด้วย mode เพศชาย (ทุกแถวที่เป็น NaN)
df_m = df.copy()
df_m[COL_AGE] = df_m[COL_AGE].fillna(male_mode)

# %%
# ก่อนเติม (ไม่รวม missing)
before = df[COL_AGE].dropna()

# เติมด้วย mode เพศหญิง (ทุกแถวที่เป็น NaN)
df_f = df.copy()
df_f[COL_AGE] = df_f[COL_AGE].fillna(female_mode)

# เติมด้วย mode เพศชาย (ทุกแถวที่เป็น NaN)
df_m = df.copy()
df_m[COL_AGE] = df_m[COL_AGE].fillna(male_mode)

# %%
# Calculate distributions after imputation
p_before = before.value_counts(normalize=True).reindex(age_order, fill_value=0)
p_female = df_f[COL_AGE].value_counts(normalize=True).reindex(age_order, fill_value=0)
p_male = df_m[COL_AGE].value_counts(normalize=True).reindex(age_order, fill_value=0)

x = range(len(age_order))

plt.figure(figsize=(9,5))
plt.plot(x, p_before.values, marker='o', label='Before (non-missing)')
plt.plot(x, p_female.values, marker='o', label='Impute: Female mode')
plt.plot(x, p_male.values,   marker='o', label='Impute: Male mode')

plt.xticks(list(x), age_order)
plt.ylabel('Proportion')
plt.title('Age range distribution: before vs imputed by female/male mode')
plt.legend()
plt.grid(True, alpha=0.2)
plt.tight_layout()
plt.show()

# %%
SS_df4 = SS_df2[~SS_df2['Longitude'].isnull()]
SS_df4
# Out:
#                           Type                       Date  \
# 4                Person search  2025-01-02T03:19:44+00:00
# 5    Person and Vehicle search  2025-01-02T03:23:13+00:00
# 6                Person search  2025-01-02T17:38:36+00:00
# 8                Person search  2025-01-02T21:56:33+00:00
# 9                Person search  2025-01-03T13:28:06+00:00
# ..                         ...                        ...
# 149  Person and Vehicle search  2025-01-31T11:28:02+00:00
# 150              Person search  2025-01-31T13:26:41+00:00
# 151              Person search  2025-01-31T13:40:18+00:00
# 152              Person search  2025-01-31T16:01:47+00:00
# 153              Person search  2025-01-31T22:29:53+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 4                             NaN                 NaN  51.510042  -0.120439
# 5                             NaN                 NaN  51.510042  -0.120439
# ...

# %%
from matplotlib import pyplot as plt

# %%
SS_cut = SS_df4[(SS_df4['Longitude'] > bp1['whiskers'][0].get_xdata()[1])& (SS_df4['Longitude'] < bp1['whiskers'][1].get_xdata()[1])]
SS_cut
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1120133030.py in <cell line: 0>()
# ----> 1 SS_cut = SS_df4[(SS_df4['Longitude'] > bp1['whiskers'][0].get_xdata()[1])& (SS_df4['Longitude'] < bp1['whiskers'][1].get_xdata()[1])]
#       2 SS_cut
#
# NameError: name 'bp1' is not defined

# %%
bp1 = plt.boxplot(SS_df4[~SS_df2['Longitude'].isnull()]['Longitude'],whis=0.8,vert=False)

# %%
SS_cut[SS_cut['Longitude']>bp1['w']

# %%
bp1['fliers']

# %%
bp1['fliers'][0]

# %%
bp1['fliers'][0].get_xdata()
# Out:
# array([-0.120439, -0.120439, -0.112953, -0.068095, -0.061248, -0.061248,
#        -0.061248, -0.065495])

# %%
bp1['whiskers']

# %%
bp1['whiskers'][0]

# %%
bp1['whiskers'][0].get_xdata()[1]
# Out:
# np.float64(-0.108894)

# %%
bp1['whiskers'][1].get_xdata()[1]
# Out:
# np.float64(-0.072148)

# %%
# Out:
#                           Type                       Date  \
# 4                Person search  2025-01-02T03:19:44+00:00
# 5    Person and Vehicle search  2025-01-02T03:23:13+00:00
# 6                Person search  2025-01-02T17:38:36+00:00
# 8                Person search  2025-01-02T21:56:33+00:00
# 9                Person search  2025-01-03T13:28:06+00:00
# ..                         ...                        ...
# 149  Person and Vehicle search  2025-01-31T11:28:02+00:00
# 150              Person search  2025-01-31T13:26:41+00:00
# 151              Person search  2025-01-31T13:40:18+00:00
# 152              Person search  2025-01-31T16:01:47+00:00
# 153              Person search  2025-01-31T22:29:53+00:00
#
#      Part of a policing operation  Policing operation   Latitude  Longitude  \
# 4                             NaN                 NaN  51.510042  -0.120439
# 5                             NaN                 NaN  51.510042  -0.120439
# ...

# %%
# โชว์หัวตาราง 10 แถวแรก (ไม่มีค่าที่ลบออกแล้ว)
SS_df3.head(10)
# Out:
#                          Type                       Date  \
# 4               Person search  2025-01-02T03:19:44+00:00
# 5   Person and Vehicle search  2025-01-02T03:23:13+00:00
# 6               Person search  2025-01-02T17:38:36+00:00
# 8               Person search  2025-01-02T21:56:33+00:00
# 9               Person search  2025-01-03T13:28:06+00:00
# 11  Person and Vehicle search  2025-01-03T19:21:47+00:00
# 12  Person and Vehicle search  2025-01-03T20:22:07+00:00
# 13              Person search  2025-01-03T21:13:46+00:00
# 14  Person and Vehicle search  2025-01-03T21:34:15+00:00
# 16              Person search  2025-01-04T00:59:11+00:00
#
#     Part of a policing operation  Policing operation   Latitude  Longitude  \
# 4                            NaN                 NaN  51.510042  -0.120439
# 5                            NaN                 NaN  51.510042  -0.120439
# 6                            NaN                 NaN  51.518231  -0.112953
# ...

# %%
plt.boxplot(SS_df3['Longitude'].dropna(), vert=False, whis=0.8)
plt.title("Boxplot of Longitude (after removing outliers)")
plt.show()

# %%
bp2 = plt.boxplot(SS_df3[~SS_df2['Longitude'].isnull()]['Longitude'],whis=0.8,vert=False)
bp2
# Out:
# /tmp/ipython-input-3949009231.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   bp2 = plt.boxplot(SS_df3[~SS_df2['Longitude'].isnull()]['Longitude'],whis=0.8,vert=False)
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc787e2da90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc787ff7b60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc787ff7410>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc787e68140>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc787e683b0>],
#  'means': []}

# %% [markdown]
# *ข้อความตัวเอียง*#Pre-processing
# missing data handling

# %% [markdown]
# ### 1 ลบทิ้ง drobna()

# %%
import pandas as pd #import pandas คือ โหลด package มีชื่อว่า pandas มาใช้ (We use import to pandas define a package that we are using)
pd.read_csv('/content/2025-05-warwickshire-stop-and-search.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-449889692.py in <cell line: 0>()
#       1 import pandas as pd #import pandas คือ โหลด package มีชื่อว่า pandas มาใช้ (We use import to pandas define a package that we are using)
# ----> 2 pd.read_csv('/content/2025-05-warwickshire-stop-and-search.csv')
#
# ...

# %% [markdown]
# * NA - Not Authorized
# * NaN - Not a Number
# * Null
# * None

# %% [markdown]
# # Query rows
# .ใช้ list ของ logic
# ที่มีขนาดความยาวเท่ากับขนาดของ row ของความยาวนั้น

# %%
SS_df.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3438525385.py in <cell line: 0>()
# ----> 1 SS_df.dropna()
#
# NameError: name 'SS_df' is not defined

# %%
SS_df = pd.read_csv('/content/2025-05-warwickshire-stop-and-search.csv')
display(SS_df.isnull().sum())
# Out:
# Type                                          0
# Date                                          0
# Part of a policing operation                  0
# Policing operation                          110
# Latitude                                    110
# Longitude                                   110
# Gender                                        1
# Age range                                    14
# Self-defined ethnicity                        1
# Officer-defined ethnicity                    12
# Legislation                                   0
# Object of search                              0
# Outcome                                       0
# Outcome linked to object of search            0
# Removal of more than just outer clothing      0
# dtype: int64

# %% [markdown]
# ไฟล์ .CSV (csv => comma separated values)
# - ใช้เครื่องหมาย comma ในการแบ่ง(คั่น)แต่ละ Columns
# - ขึ้น record ใหม่จะใช้การ Enter
#
# CSV File (csv => comma separated values)
# - use comma (,) to separate values
# - use new line (enter,\n) to separate data points

# %% [markdown]
# # Load data แบบ one-time-use

# %%
data_df = pd.read_csv('/content/data.csv')

# %% [markdown]
# - 🍀function ชื่อว่า "read_csv" จะเรียกข้อมูลให้ออกมาอยู่ใน format ของตาราง

# %%
data_df #เรียกดูตาราง csv.
# Out:
#    Car_ID         Model   Year   Value   Pers_ID
# 0     101       Bentley   1973  100000         0
# 1     102   Rolls Royce   1965  330000         0
# 2     103       Peugeot   1993     500         3

# %% [markdown]
# ****

# %% [markdown]
# # Load data แบบ ผูกกับไดรฟ์

# %%
## Import data from google drive:
import pandas as pd
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# prompt: อ่านข้อมูล csv ไฟล์ from google drive
#=====  > Input part
main_path = '/content/drive/MyDrive' # Replace 'your_file.csv' with the actual path to your CSV
folder_data = 'Multivariate'
file_data = ['Indian_Kids_Screen_Time.csv']

# %%
pd.read_csv('/content/drive/MyDrive/MSC_DPDM2025/2025-01/2025-01-cambridgeshire-stop-and-search.csv')
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T17:30:00+00:00
# 1                Person search  2025-01-02T00:28:00+00:00
# 2                Person search  2025-01-02T00:38:00+00:00
# 3                Person search  2025-01-02T14:00:00+00:00
# 4    Person and Vehicle search  2025-01-02T16:50:00+00:00
# ..                         ...                        ...
# 219              Person search  2025-01-31T19:45:00+00:00
# 220  Person and Vehicle search  2025-01-31T20:11:00+00:00
# 221  Person and Vehicle search  2025-01-31T23:30:00+00:00
# 222              Person search  2025-01-31T23:40:00+00:00
# 223              Person search  2025-01-31T23:45:00+00:00
#
#     Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                            NaN                 NaN  52.221213  -0.297510
# 1                            NaN                 NaN  52.572933  -0.241374
# ...

# %%
pd.read_csv('/content/2025-01-cambridgeshire-stop-and-search_edit.csv', skiprows=1)
# Out:
#                           Type                       Date  \
# 0                Person search  2025-01-01T17:30:00+00:00
# 1                Person search  2025-01-02T00:28:00+00:00
# 2                Person search  2025-01-02T00:38:00+00:00
# 3                Person search  2025-01-02T14:00:00+00:00
# 4    Person and Vehicle search  2025-01-02T16:50:00+00:00
# ..                         ...                        ...
# 219              Person search  2025-01-31T19:45:00+00:00
# 220  Person and Vehicle search  2025-01-31T20:11:00+00:00
# 221  Person and Vehicle search  2025-01-31T23:30:00+00:00
# 222              Person search  2025-01-31T23:40:00+00:00
# 223              Person search  2025-01-31T23:45:00+00:00
#
#     Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                            NaN                 NaN  52.221213  -0.297510
# 1                            NaN                 NaN  52.572933  -0.241374
# ...

# %% [markdown]
# ## Homework 6 ดึงตาราง ผลงานตีพิมพ์ที่เกี่ยวข้องในฐานข้อมูล Scopus โดยไม่เอา ตัวอย่าง จากไฟล์ การตีพิมพ์เผยแพร่ในวารสารที่อยู่ใน SCOPUS-.xlsx

# %%
import pandas as pd

# %%
pd.read_excela('/content/การตีพิมพ์เผยแพร่ในวารสารที่อยู่ในฐาน SCOPUS-.xlsx')
# Out:
#                                            Unnamed: 0  \
# 0                ทุนส่งเสริมการเพิ่มจํานวนทุนการศึ...
# 1                             (ภายใต้โครงการส่งเสร...
# 2   มีผลงานตีพิมพ์ที่เกี่ยวข้องในฐานข้อมูล SCOPUS ...
# 3   ชื่อ-สกุล ดร.ธนพงศ์ นามสกุล อินทระ อาจารย์ประจ...
# 4                        อาจารย์สังกัดคณะ วิทยาศาสตร์
# 5                                                 No.
# 6                                            ตัวอย่าง
# 7                                                   1
# 8                                                   2
# 9                                                   3
# 10                                                  4
# 11                                                  5
# 12                                                  6
# 13                                                  7
# 14                                                  8
# 15                                                  9
# ...

# %%
df = pd.read_excel('/content/การตีพิมพ์เผยแพร่ในวารสารที่อยู่ในฐาน SCOPUS-.xlsx', skiprows=6)
df
# Out:
#          No.                                            Authors  \
# 0   ตัวอย่าง  Ngeontae, Wittaya; Chaiendoo, Kanokwan; Ngamde...
# 1          1  Wiratchawa, Kannika; Wanna, Yupaporn; Junsawan...
# 2          2  Jarujareet, Ungkarn; Wiratchawa, Kannika; Peti...
# 3          3  Petiwathayakorn, Touchwin; Paradee, Narisara; ...
# 4          4  Srisomboon, Surapong; Intharah, Thanapong; Jar...
# 5          5  Penpong, Nutsuda; Wanna, Yupaporn; Kamjanlard,...
# 6          6               Wanna, Yupaporn; Intharah, Thanapong
# 7          7  Thiannoi, Thanyalak; Junpeng, Putcharee; Intha...
# 8          8  Panphet, Natchaya; Junpeng, Putcharee; Inthara...
# 9          9  Thiannoi, Thanyalak; Junpeng, Putcharee; Intha...
# 10        10  Paenpa, Phenjarat; Junpeng, Putcbaree; Inthara...
# 11        11  Wiratchawa, Kannika; Petiwathayakorn, Touchwin...
# 12        12  Hirunchavarod, Natthanich; Phuphatham, Pornnak...
# 13        13  Hirunchavarod, Natthanich; Dangsungnoen, Lapat...
# ...

# %%
df.drop(0)
# Out:
#    No.                                            Authors  \
# 1    1  Wiratchawa, Kannika; Wanna, Yupaporn; Junsawan...
# 2    2  Jarujareet, Ungkarn; Wiratchawa, Kannika; Peti...
# 3    3  Petiwathayakorn, Touchwin; Paradee, Narisara; ...
# 4    4  Srisomboon, Surapong; Intharah, Thanapong; Jar...
# 5    5  Penpong, Nutsuda; Wanna, Yupaporn; Kamjanlard,...
# 6    6               Wanna, Yupaporn; Intharah, Thanapong
# 7    7  Thiannoi, Thanyalak; Junpeng, Putcharee; Intha...
# 8    8  Panphet, Natchaya; Junpeng, Putcharee; Inthara...
# 9    9  Thiannoi, Thanyalak; Junpeng, Putcharee; Intha...
# 10  10  Paenpa, Phenjarat; Junpeng, Putcbaree; Inthara...
# 11  11  Wiratchawa, Kannika; Petiwathayakorn, Touchwin...
# 12  12  Hirunchavarod, Natthanich; Phuphatham, Pornnak...
# 13  13  Hirunchavarod, Natthanich; Dangsungnoen, Lapat...
# 14  14  Thonghlueng, Janpen; Ngernpimai, Sawinee; Chua...
# 15  15  Intharah, Thanapong; Wiratchawa, Kannika; Wann...
# ...

# %%
float('inf')
# Out:
# inf

# %%
float('-inf')
# Out:
# -inf

# %% [markdown]
# 2. using Python’s math module:

# %%
import math

# %%
math.inf
# Out:
# inf

# %%
-math.inf
# Out:
# -inf

# %% [markdown]
# # Function
#
# เหมาะกับงานที่มีการใช้ code ซ้ำๆ
#
# ``` python
# def ชื่อฟังก์ชั่น(input1,input2,....):
#     งานxxx
#     งานyyy
#     return output
# ```
# ``` python
# def function name(input1,input2,....):
#     process #1
#     process #2
#     return output
# ```
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ส่วนประกอบสำคัญ (four important parts of a function)**
#
# - function name (ไม่มีไม่ได้ (needed))
#
# - input
#
# - process (ไม่มีไม่ได้ (needed))
#
# - output

# %% [markdown]
# #### Example 1

# %%
def find_min(list_ex):
    min = 100000000
    for x in list_ex:
        if x < min:
            min = x #update min if น้อยกว่า

    return min

# %%
list_A = [1,5,9,-19,-2,0]
XXX = find_min(list_A)
print(XXX)
# Out:
# -19

# %%
find_min([-9,99,0,-34])
# Out:
# -34

# %% [markdown]
# #### Example 2
# Function ที่ไม่มี Output (Function without Output)
# - ไม่มีตัวแปรเก็บค่า แต่ให้แสดงค่าออกมาเลย (cannot set a value to variable)

# %%
def find_min2(list_ex): ## ไม่มีเก็บค่าในตัวแปร ให้ return
    min = 100000000
    for x in list_ex:
        if x < min:
            min = x
    print(min)

# %%
find_min2(list_A)
# Out:
# -19

# %%
YYY  = find_min2(list_A) ## ไม่เก็บค่า แต่ print ออกมาเลย ทำให้ YYY รับค่าไม่ได้
# Out:
# -19

# %%
YYY

# %% [markdown]
# #### Example 3
# Function แบบไม่มี Input (Function without Input)
#
# -- รันเมื่อไหร่ก็จะเหมือนเดิม

# %%
def Pi_val():
    return 3.1416

# %%
r = 10
print(f'พื้นที่วงกลมที่มีเส้นผ่านศูนย์กลางเท่ากับ {r} คือ {Pi_val()*r*r}')
# Out:
# พื้นที่วงกลมที่มีเส้นผ่านศูนย์กลางเท่ากับ 10 คือ 314.16

# %% [markdown]
# #### Example 4
# Function ที่มีแต่ Process อย่างเดียว (Function has only the Process part)

# %%
def draw_rectangle():
    print('======')
    print('|    |')
    print('======')

# %%
draw_rectangle()
# Out:
# ...
# |    |
# ...

# %%
def draw_hello():
    print('============')
    print('|  Hello  |')
    print('============')

# %%
draw_hello()
# Out:
# ...
# |  Hello  |
# ...

# %% [markdown]
# Function ที่ไม่มี Process จะ Run ไม่ได้ (Function without a process means error)

# %%
def draw_rectangle():
# Out:
#   File "<ipython-input-110-96ff03789653>", line 1
#     def draw_rectangle():
#                          ^
# SyntaxError: incomplete input

# %% [markdown]
# **ลักษณะของ (input type of inputs or paremeter,argument)**
#
# - จำเป็นต้องใส่ (non-default argument: you need to give an input this argument)
#
# - ไม่จำเป็นต้องใส่เพราะมี default อยู่แล้ว (default argument: you can ignore it because it has a default value)

# %%
def draw_rectangle(dbbound=True): ## ค่า default คือ True เป็น input ที่ใส่ หรือไม่่ใส่ก็ได้ (this is exmaple of default argument)
    if dbbound:
        print('========')
        print('||    ||')
        print('========')
    else:
        print('________')
        print('|      |')
        print('--------')

# %%
draw_rectangle()
# Out:
# ...
# ||    ||
# ...

# %%
draw_rectangle(True)
# Out:
# ...
# ||    ||
# ...

# %%
draw_rectangle(False)
# Out:
# ________
# |      |
# --------

# %% [markdown]
#  ไม่มี input ที่เป็นค่า default (when you call a function that require non-default argument without input, it will return error)

# %%
find_min2() ## ไม่มี input ที่เป็นค่า default
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-b69793295198> in <cell line: 1>()
# ----> 1 find_min2(2) ## ไม่มี input ที่เป็นค่า default
#
# <ipython-input-100-f36e60c6b73b> in find_min2(list_ex)
#       1 def find_min2(list_ex): ## ไม่มีเก็บค่าในตัวแปร ให้ return
#       2     min = 100000000
# ----> 3     for x in list_ex:
#       4         if x < min:
#       5             min = x
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# นำ input ที่จำเป็นต้องใส่มาไว้ด้านหน้าก่อน (when define a function, you have to put non-default argument first)

# %%
#''' นำ input ที่จำเป็นต้องใส่มาไว้ด้านหน้าก่อน (when define a function, you have to put non-default argument first)
def draw_rectangle(size,dbbound=True): ## size เป็น input ที่ต้องใส่ (size in non-default argument)
    if dbbound:
        up = '='
        space = ' '
        print(f'{(size+4)*up}')
        print(f'||{size*space}||')
        print(f'{(size+4)*up}')
    else:
        up = '-'
        space = ' '
        print(f'{(size+4)*up}')
        print(f'|{size*space}|')
        print(f'{(size+4)*up}')

# %%
draw_rectangle() ## ถ้าไม่ใส่ input ที่จำเป็นต้องใส่ จะ Errors
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-88c3012a2a69> in <cell line: 1>()
# ----> 1 draw_rectangle() ## ถ้าไม่ใส่ input ที่จำเป็นต้องใส่ จะ Errors
#
# TypeError: draw_rectangle() missing 1 required positional argument: 'size'

# %%
draw_rectangle(10,False)
# Out:
# --------------
# |          |
# --------------

# %% [markdown]
# ไม่ได้ใส่ parameter ตามลำดับ แต่ใส่ parameter ที่จำเป็นต้องใส่ก็สามารถ run ได้ ถ้าใส่ชื่อของ parameter ด้วย
#
# you don't have to follow the order of the arguments if you specify what arguments are what

# %%
draw_rectangle(dbbound=False,size=7)
# Out:
# -----------
# |       |
# -----------

# %%
draw_rectangle(size=7)
# Out:
# ...
# ||       ||
# ...

# %% [markdown]
# #### Example 5
#
# สร้าง function
#
# - วาด 4 เหลี่ยม ให้สามารถกำหนด ความยาว เเละ ความกว้าง ได้
# - เเต่ถ้าใส่ parameter ตัวเดียวก็ให้วาด 4 เหลี่ยม จัสตุรัส ที่มี ความยาว เเละ ความกว้าง เท่ากับ parameter ที่ใส่
#
# ให้ปริ้น ความกว้างxความยาวของสี่เหลี่ยม
#
#
# (ให้ปริ้น ความกว้าง x ความยาวของ สี่เหลี่ยม)
#
# create a function that:
#
# - draw a rectangle that you can specify width and height of it
# - but when user input only one argument draw square
#
#
# **ตัวอย่าง**
#
# rext(3,5)
# > 3 x 5
#
# rext(7)
#
# > 7 x 7

# %%
def draw_rectagle(W, H): #เติมค่่า ตัวหนึ่งได้เเต่ใช้สองตัว
    print(f'{W} x {H}')
draw_rectagle(3, 5)
# Out:
# 3 x 5

# %%
def draw_rectagle(W, H=True): #เติมค่่า ตัวหนึ่งได้เเต่ใช้สองตัว
    if H == True: #เช็ค if parameter 1 ตัว
        H=W
    print(f'{W} x {H}')

# %%
draw_rectagle(3)
# Out:
# 3 x 3

# %%
draw_rectagle(3,5)
# Out:
# 3 x 5

# %%
def draw_rectagle(W, H=True):
    if H ==True:
       up = '-'
       side = '|'
       space = W-1
       print(f'{W*up}')
       for i in range(W):
           print(f'{side}{space*" "}{side}')
       print(f'{W*up}')
       print((f'{W} x {W}'))
    else:
        up = '-'
        side = '|'
        space = W-1
        print(f'{W*up}')
        for i in range(H):
            print(f'{side}{space*" "}{side}')
        print(f'{W*up}')
        print((f'{W} x {H}'))

# %%
draw_rectagle(W=5)
# Out:
# -----
# |    |
# |    |
# |    |
# |    |
# |    |
# -----
# 5 x 5

# %%
draw_rectagle(W=5,H=10)
# Out:
# -----
# |    |
# |    |
# |    |
# |    |
# |    |
# |    |
# |    |
# |    |
# |    |
# |    |
# -----
# 5 x 10

# %%
draw_rectagle(W=10,H=10)
# Out:
# ----------
# |         |
# |         |
# |         |
# |         |
# |         |
# |         |
# |         |
# |         |
# |         |
# |         |
# ----------
# 10 x 10

# %%
draw_rectagle(W=5,H=5)
# Out:
# -----
# |    |
# |    |
# |    |
# |    |
# |    |
# -----
# 5 x 5

# %% [markdown]
# ****

# %% [markdown]
# ### Example
#
# create a function that
# 1. sort a list
# 2. you can specify to the function that to sort it ascending or descending  with ascending as default
# 3. have 2 argument one default and one non-default

# %%
list_ex = [1, 5, 9, -19, -2, 0]

def sort(list, descending=False):
# sort คือจัดเรียง ถ้าเราใส่ list จะเรียง list ให้โดย descending=False เรียงจากน้อยไปมากเป็นค่าเริ่มต้น
 #(sort is sorted. If we enter a list, the list will be sorted by descending=False . Sort ascending is default.)
  return sorted(list, reverse=descending)

# %%
sort(list_ex)
# Out:
# [-19, -2, 0, 1, 5, 9]

# %%
sort(list_ex,True)
# Out:
# [9, 5, 1, 0, -2, -19]

# %% [markdown]
# คำตอบที่ถูกต้องที่สุด
#
# The most correct answer

# %%
def sorting(input_number,type=True):
  n = len(input_number)
  if type == True:
    for i in range(n):
      for j in range(0,n-i-1):
        if input_number[j] > input_number[j+1]:
          input_number[j], input_number[j+1] = input_number[j+1], input_number[j]
  else:
    for i in range(n):
      for j in range(0,n-i-1):
        if input_number[j+1] > input_number[j]:
          input_number[j], input_number[j+1] = input_number[j+1],input_number[j]
  return input_number

# %%
sorting(list_ex)
# Out:
# [-19, -2, 0, 1, 5, 9]

# %%
sorting(list_ex,False)
# Out:
# [9, 5, 1, 0, -2, -19]

# %% [markdown]
# ***

# %% [markdown]
# # HW 1.5 เขียน function  ของ  Hw 1
#
# เพิ่มว่าไม่มีตัวอักษร ตัวนี้ใน list_aa  ex เช่นจะหาคำว่า  zoo
#
# แล้วไม่มี  z ใน list aa มีแต่ oo

# %%
def analyze_letters(list_aa, word, list_name):
  # เก็บตัวอักษรใน list_aa ว่ามีตัวอะไรบ้าง
    word_split = []
    for i in list_aa:
        for j in i: # ตัวอักษรในคำที่ศัพท์ที่มี
            if j not in word_split:
                word_split.append(j)

   #หาตัวอักษรที่ต้องการ
    word_collect = []
    for w in word:
        letter_collect = []
        for l in w:
            if l in word_split:
                letter_collect.append(l)
            # else:
            #     print(f'The letter {l} not in list_aa')
        word_collect.append(''.join(letter_collect)) #รวมตัวอักษรในคำที่ต้องการหา

    print(f'List of word found --> {word_collect}')
    for c in word: # print คำที่ต้องการหาก่อน
        print(c)
        for l in c:
            found = False #Tracks Status, Avoids Redundant Prints, Ensures Complete Check
            for i in list_aa:
                if l in i:
                    print(f'The letter {l} can be found in the word {i} in {list_name}')
                    found = True
                    break # ถ้าเจอใน 1 คำของ list_aa แล้วออกจากลูป  #break statement in the inner loop to exit once the letter is found in list_aa.
            if not found:
              print(f'The letter {l} not in {list_name}')
        print('-'*100)

# %% [markdown]
# ## test 1

# %%
list_aa
# Out:
# ['chiken',
#  'water',
#  'vegetable',
#  'rice',
#  'plate',
#  'spoon',
#  'fork',
#  'knife',
#  'apple']

# %%
word = ['nice','spork','warick']

# %%
analyze_letters(list_aa, word, 'list_aa')
# Out:
# List of word found --> ['nice', 'spork', 'warick']
# nice
# The letter n can be found in the word chiken in list_aa
# The letter i can be found in the word chiken in list_aa
# The letter c can be found in the word chiken in list_aa
# The letter e can be found in the word chiken in list_aa
# ----------------------------------------------------------------------------------------------------
# spork
# The letter s can be found in the word spoon in list_aa
# The letter p can be found in the word plate in list_aa
# The letter o can be found in the word spoon in list_aa
# The letter r can be found in the word water in list_aa
# The letter k can be found in the word chiken in list_aa
# ----------------------------------------------------------------------------------------------------
# warick
# The letter w can be found in the word water in list_aa
# The letter a can be found in the word water in list_aa
# The letter r can be found in the word water in list_aa
# ...

# %% [markdown]
# ## test 2

# %%
word = ['nice','spork','warick','zoo', 'spider man']

# %%
analyze_letters(list_aa, word, 'list_aa')
# Out:
# List of word found --> ['nice', 'spork', 'warick', 'oo', 'spieran']
# nice
# The letter n can be found in the word chiken in list_aa
# The letter i can be found in the word chiken in list_aa
# The letter c can be found in the word chiken in list_aa
# The letter e can be found in the word chiken in list_aa
# ----------------------------------------------------------------------------------------------------
# spork
# The letter s can be found in the word spoon in list_aa
# The letter p can be found in the word plate in list_aa
# The letter o can be found in the word spoon in list_aa
# The letter r can be found in the word water in list_aa
# The letter k can be found in the word chiken in list_aa
# ----------------------------------------------------------------------------------------------------
# warick
# The letter w can be found in the word water in list_aa
# The letter a can be found in the word water in list_aa
# The letter r can be found in the word water in list_aa
# ...

# %% [markdown]
# ## test 3

# %%
new_list = ['mathematics','physics','chemistry','biology','computer science','art','music','history','geography']

# %%
word = ['skullpanda','upsetduck','shin chan', 'monster inc', 'boo', 'molly space']

# %%
analyze_letters(new_list, word, 'new_list')
# Out:
# List of word found --> ['sullpana', 'upsetuc', 'shin chan', 'monster inc', 'boo', 'molly space']
# skullpanda
# The letter s can be found in the word mathematics in new_list
# The letter k not in new_list
# The letter u can be found in the word computer science in new_list
# The letter l can be found in the word biology in new_list
# The letter l can be found in the word biology in new_list
# The letter p can be found in the word physics in new_list
# The letter a can be found in the word mathematics in new_list
# The letter n can be found in the word computer science in new_list
# The letter d not in new_list
# The letter a can be found in the word mathematics in new_list
# ----------------------------------------------------------------------------------------------------
# upsetduck
# The letter u can be found in the word computer science in new_list
# The letter p can be found in the word physics in new_list
# The letter s can be found in the word mathematics in new_list
# ...

# %%
# # เก็บตัวอักษรใน list_aa ว่ามีตัวอะไรบ้าง
# word_split = []
# for i in list_aa:
#   for j in i:
#       if j not in word_split:
#         word_split.append(j)
# word_collect = []
# for i in word:
#   letter_collect = []
#   for j in i: # ตัวอักษรในคำที่ต้องการหา
#     if j in word_split:
#        letter_collect.append(j)
#     else:
#         print(f'The letter {j} not in list_aa')
#   word_collect.append(''.join(letter_collect))

# for i in word_collect:
#   print(i)
#   for a in word:
#     for b in a: # ตัวอักษรในคำที่ต้องการหา
#      if b in word_split:
#        for k in list_aa:
#           for l in k:
#             if l == b:
#               print(f'The letter {b} can found in the word {k} in list_aa')
# Out:
# The letter z not in list_aa
# nice
# The letter n can found in the word chiken in list_aa
# The letter n can found in the word spoon in list_aa
# The letter n can found in the word knife in list_aa
# The letter i can found in the word chiken in list_aa
# The letter i can found in the word rice in list_aa
# The letter i can found in the word knife in list_aa
# The letter c can found in the word chiken in list_aa
# The letter c can found in the word rice in list_aa
# The letter e can found in the word chiken in list_aa
# The letter e can found in the word water in list_aa
# The letter e can found in the word vegetable in list_aa
# The letter e can found in the word vegetable in list_aa
# The letter e can found in the word vegetable in list_aa
# The letter e can found in the word rice in list_aa
# The letter e can found in the word plate in list_aa
# The letter e can found in the word knife in list_aa
# The letter e can found in the word apple in list_aa
# ...

# %%
# for k in list_aa:
#   print(k)
#   for l in k:
#     print(l)
# Out:
# chiken
# c
# h
# i
# k
# e
# n
# water
# w
# a
# t
# e
# r
# vegetable
# v
# e
# g
# e
# t
# a
# b
# l
# e
# rice
# r
# i
# c
# e
# plate
# p
# l
# a
# t
# e
# spoon
# s
# p
# o
# o
# n
# fork
# f
# o
# r
# k
# knife
# k
# n
# i
# f
# e
# apple
# a
# p
# p
# l
# e

# %%
SS_df = pd.read_csv('/content/2025-05-warwickshire-stop-and-search.csv')
display(SS_df.isnull().sum())
# Out:
# Type                                          0
# Date                                          0
# Part of a policing operation                  0
# Policing operation                          110
# Latitude                                    110
# Longitude                                   110
# Gender                                        1
# Age range                                    14
# Self-defined ethnicity                        1
# Officer-defined ethnicity                    12
# Legislation                                   0
# Object of search                              0
# Outcome                                       0
# Outcome linked to object of search            0
# Removal of more than just outer clothing      0
# dtype: int64
